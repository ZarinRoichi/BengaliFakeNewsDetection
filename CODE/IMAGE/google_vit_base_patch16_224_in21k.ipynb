# %%
# ============================================================
# STAGE 2 – INSTALLS (run once in this notebook)
# ============================================================
# !pip install -q torch torchvision transformers datasets accelerate scikit-learn seaborn

# %%
# ============================================================
# 1) IMPORTS + SEED
# ============================================================
import os
import json
import random
import numpy as np

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler

from torchvision import transforms
from PIL import Image

from transformers import (
    ViTForImageClassification,
    ViTImageProcessor,
    Trainer,
    TrainingArguments,
    EvalPrediction
)

from sklearn.metrics import (
    classification_report,
    accuracy_score,
    f1_score,
    confusion_matrix,
    roc_curve,
    auc
)
from sklearn.utils.class_weight import compute_class_weight

from google.colab import drive
import matplotlib.pyplot as plt
import seaborn as sns

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

set_seed(42)
print("✅ Seed set to 42")
# Out:
# ✅ Seed set to 42

# %%
# ============================================================
# 2) PATHS (Drive + PREPROC + OUTPUT ROOT)
# ============================================================
drive.mount('/content/drive')

PREPROC_ROOT = "/content/drive/MyDrive/MultiBanFake/preprocessed"
OUTPUT_ROOT  = "/content/drive/MyDrive/MultiBanFake/outputs_vit"
os.makedirs(PREPROC_ROOT, exist_ok=True)
os.makedirs(OUTPUT_ROOT, exist_ok=True)

print("PREPROC_ROOT:", PREPROC_ROOT)
print("OUTPUT_ROOT :", OUTPUT_ROOT)
# Out:
# Mounted at /content/drive
# PREPROC_ROOT: /content/drive/MyDrive/MultiBanFake/preprocessed
# OUTPUT_ROOT : /content/drive/MyDrive/MultiBanFake/outputs_vit

# %%
# ============================================================
# 3) LOAD PREPROCESSED DATA (NPZ)
# ============================================================
train_npz = np.load(os.path.join(PREPROC_ROOT, "train_npz.npz"))
val_npz   = np.load(os.path.join(PREPROC_ROOT, "val_npz.npz"))
test_npz  = np.load(os.path.join(PREPROC_ROOT, "test_npz.npz"))

with open(os.path.join(PREPROC_ROOT, "classes.json"), "r") as f:
    classes = json.load(f)

print("Train images:", train_npz["images"].shape, "labels:", train_npz["labels"].shape)
print("Val images  :", val_npz["images"].shape, "labels:", val_npz["labels"].shape)
print("Test images :", test_npz["images"].shape, "labels:", test_npz["labels"].shape)
print("Classes:", classes)

num_labels = len(classes)
label_names = classes
label2id = {name: i for i, name in enumerate(label_names)}
id2label = {i: name for name, i in label2id.items()}
# Out:
# Train images: (7603, 224, 224, 3) labels: (7603,)
# Val images  : (957, 224, 224, 3) labels: (957,)
# Test images : (957, 224, 224, 3) labels: (957,)
# Classes: ['Fake', 'Real']

# %%
# ============================================================
# 4) DATASET CLASS (preprocessed numpy + dynamic augmentation)
# ============================================================
class CachedImageDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        # images: numpy [N, H, W, C], uint8
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return self.images.shape[0]

    def __getitem__(self, idx):
        img = self.images[idx]              # [H, W, C], uint8
        lbl = int(self.labels[idx])

        img = Image.fromarray(img)          # numpy -> PIL
        if self.transform:
            img = self.transform(img)       # aug + ToTensor + Normalize

        return {
            "pixel_values": img,
            "labels": torch.tensor(lbl, dtype=torch.long)
        }

# %%
# ============================================================
# 5) TRANSFORMS (ViT-friendly, augmentation + eval)
# ============================================================
processor = ViTImageProcessor.from_pretrained("google/vit-base-patch16-224-in21k")

train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224, scale=(0.9, 1.0)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(5),
    transforms.ColorJitter(brightness=0.1, contrast=0.1, saturation=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std),
])

eval_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std),
])

train_ds = CachedImageDataset(
    images=train_npz["images"],
    labels=train_npz["labels"],
    transform=train_transform,
)
val_ds = CachedImageDataset(
    images=val_npz["images"],
    labels=val_npz["labels"],
    transform=eval_transform,
)
test_ds = CachedImageDataset(
    images=test_npz["images"],
    labels=test_npz["labels"],
    transform=eval_transform,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]

# %%
# ============================================================
# 6) IMBALANCE HANDLING (class weights + sample weights)
# ============================================================
train_labels = train_npz["labels"]
class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_labels),
    y=train_labels,
)
print("Class weights:", class_weights)

sample_weights = np.array([class_weights[label] for label in train_labels], dtype=np.float64)
sample_weights_torch = torch.from_numpy(sample_weights)
print("Sample weights shape:", sample_weights_torch.shape)
# Out:
# Class weights: [1.00224097 0.99776903]
# Sample weights shape: torch.Size([7603])

# %%
# ============================================================
# 7) VIT MODEL LOAD
# ============================================================
vit_model = ViTForImageClassification.from_pretrained(
    "google/vit-base-patch16-224-in21k",
    num_labels=num_labels,
    id2label=id2label,
    label2id=label2id,
)
# Out:
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# ============================================================
# 8) METRICS
# ============================================================
def compute_metrics(eval_pred: EvalPrediction):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)

    acc = accuracy_score(labels, preds)
    f1_weighted = f1_score(labels, preds, average="weighted")

    return {
        "accuracy": acc,
        "f1_weighted": f1_weighted,
    }

# %%
# ============================================================
# 9) CUSTOM TRAINER (sampler + class-weight + label smoothing)
# ============================================================
class CustomTrainer(Trainer):
    def __init__(self, *args, class_weights=None, sample_weights=None, **kwargs):
        """
        CustomTrainer:
          - class_weights: used in CrossEntropyLoss (for class imbalance)
          - sample_weights: used in WeightedRandomSampler
        """
        super().__init__(*args, **kwargs)

        # ----- class_weights -----
        if class_weights is not None:
            if isinstance(class_weights, torch.Tensor):
                self.class_weights = class_weights.detach().clone().float()
            else:
                self.class_weights = torch.tensor(class_weights, dtype=torch.float)
        else:
            self.class_weights = None

        # ----- sample_weights -----
        if sample_weights is not None:
            if isinstance(sample_weights, torch.Tensor):
                # warning fix: tensor থেকে নতুন tensor বানাতে detach().clone() ব্যবহার করি
                self.sample_weights = sample_weights.detach().clone().double()
            else:
                self.sample_weights = torch.tensor(sample_weights, dtype=torch.double)
        else:
            self.sample_weights = None

    def compute_loss(
        self,
        model,
        inputs,
        return_outputs: bool = False,
        num_items_in_batch: int | None = None,  # <<==== main HF change
    ):
        """
        HF Trainer এখন compute_loss(..., num_items_in_batch=...) call করে।
        তাই signature-এ num_items_in_batch রাখতে হবে।
        """
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits

        # class_weights থাকলে weighted CE, সাথে label smoothing
        if self.class_weights is not None:
            cw = self.class_weights.to(logits.device)
            loss_fct = nn.CrossEntropyLoss(weight=cw, label_smoothing=0.1)
        else:
            loss_fct = nn.CrossEntropyLoss(label_smoothing=0.1)

        loss = loss_fct(logits, labels)

        if return_outputs:
            return loss, outputs
        return loss

    def get_train_dataloader(self):
        """
        train dataloader override করে WeightedRandomSampler use করছি,
        যাতে imbalanced dataset handle করা যায়।
        """
        # sample_weights না থাকলে default dataloader
        if self.sample_weights is None:
            return super().get_train_dataloader()

        # IterableDataset হলে custom sampler use করা যাবে না
        if isinstance(self.train_dataset, torch.utils.data.IterableDataset):
            return super().get_train_dataloader()

        # WeightedRandomSampler expect করে 1D tensor / list of weights
        sampler = WeightedRandomSampler(
            weights=self.sample_weights,
            num_samples=len(self.sample_weights),
            replacement=True,
        )

        return DataLoader(
            self.train_dataset,
            batch_size=self.args.train_batch_size,
            sampler=sampler,
            collate_fn=self.data_collator,
            drop_last=self.args.dataloader_drop_last,
            num_workers=self.args.dataloader_num_workers,
            pin_memory=self.args.dataloader_pin_memory,
        )

# %%
# ============================================================
# 10) TRAINING ARGUMENTS
#    (no evaluation_strategy/save_strategy for old HF versions)
# ============================================================

output_dir = os.path.join(OUTPUT_ROOT, "vit_model_full")
os.makedirs(output_dir, exist_ok=True)


training_args = TrainingArguments(
    output_dir=output_dir,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=16,
    num_train_epochs=3,
    learning_rate=3e-5,
    weight_decay=0.01,

    # পুরনো version compatible setup (evaluation_strategy নাই)
    eval_steps=500,
    save_steps=500,
    logging_steps=50,

    fp16=True,
    save_total_limit=2,
    remove_unused_columns=False,
)

# %%
# ============================================================
# 11) TRAIN VIT,15a26bfde02e39ba547185222150f57c5c5d8e02
# ============================================================
trainer = CustomTrainer(
    model=vit_model,
    args=training_args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    compute_metrics=compute_metrics,

    # custom loss arguments
    class_weights=class_weights,
    sample_weights=sample_weights_torch,
)

trainer.train()

# ---- SAVE BEST MODEL ----
best_model_dir = os.path.join(OUTPUT_ROOT, "vit_best_model")
os.makedirs(best_model_dir, exist_ok=True)
trainer.save_model(best_model_dir)

print("✅ Saved best ViT model to:", best_model_dir)
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: zarin-cse-20210104111 (zarin-cse-20210104111-ahsanullah-university-of-science-t) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.22.3
# Run data is saved locally in <code>/content/wandb/run-20251119_201148-ovzg2hkr</code>
# Syncing run <strong><a href='https://wandb.ai/zarin-cse-20210104111-ahsanullah-university-of-science-t/huggingface/runs/ovzg2hkr' target="_blank">warm-sea-59</a></strong> to <a href='https://wandb.ai/zarin-cse-20210104111-ahsanullah-university-of-science-t/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/zarin-cse-20210104111-ahsanullah-university-of-science-t/huggingface' target="_blank">https://wandb.ai/zarin-cse-20210104111-ahsanullah-university-of-science-t/huggingface</a>
#  View run at <a href='https://wandb.ai/zarin-cse-20210104111-ahsanullah-university-of-science-t/huggingface/runs/ovzg2hkr' target="_blank">https://wandb.ai/zarin-cse-20210104111-ahsanullah-university-of-science-t/huggingface/runs/ovzg2hkr</a>
#     <div>
#
#       <progress value='2853' max='2853' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2853/2853 06:38, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.695100</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.686400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.680500</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.672400</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.663300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.655100</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.660700</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.641600</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.632000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.635200</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.631500</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.620400</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.621900</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.593100</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.613300</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.591800</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.593600</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.579300</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.581900</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.559200</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.526600</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.585700</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.531400</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.535100</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.519500</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.551400</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.519100</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.528600</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.521800</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.524200</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.498300</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.507600</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.499200</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.508400</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.488100</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.474600</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.485300</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.448900</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.453400</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.482600</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.445900</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.467800</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.439700</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.445800</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.461400</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.422300</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.411200</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.430500</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.431700</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.407300</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.403200</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.398100</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.437000</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.393200</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.425500</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.417600</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.394500</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ Saved best ViT model to: /content/drive/MyDrive/MultiBanFake/outputs_vit/vit_best_model

# %%
# ============================================================
# 12) RICH EVAL + SAVE (REPORT + CONFUSION + ROC + PROBS)
# ============================================================
vit_preds = trainer.predict(test_ds)
logits = vit_preds.predictions
vit_pred_labels = np.argmax(logits, axis=-1)
vit_true_labels = vit_preds.label_ids

print("\n📊 Classification Report (ViT):\n")
print(classification_report(
    vit_true_labels,
    vit_pred_labels,
    target_names=label_names,
    digits=4
))

cm = confusion_matrix(vit_true_labels, vit_pred_labels)
plt.figure(figsize=(4,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=label_names, yticklabels=label_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix (ViT)")
plt.show()

if num_labels == 2:
    vit_probs_arr = torch.softmax(torch.tensor(logits), dim=-1).numpy()
    fpr, tpr, _ = roc_curve(vit_true_labels, vit_probs_arr[:, 1])
    roc_auc = auc(fpr, tpr)
    plt.figure()
    plt.plot(fpr, tpr, label=f"ViT (AUC = {roc_auc:.3f})")
    plt.plot([0,1], [0,1], linestyle="--")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC Curve (ViT)")
    plt.legend()
    plt.show()

vit_report_dict = classification_report(
    vit_true_labels,
    vit_pred_labels,
    target_names=label_names,
    digits=4,
    output_dict=True,
)

vit_report_path = os.path.join(OUTPUT_ROOT, "vit_classification_report_full.json")
vit_probs_path  = os.path.join(OUTPUT_ROOT, "vit_stack_probs_full.json")

with open(vit_report_path, "w") as f:
    json.dump(vit_report_dict, f, indent=4)

vit_probs_list = vit_probs_arr.tolist()
with open(vit_probs_path, "w") as f:
    json.dump({
        "vit_probs": vit_probs_list,
        "true_labels": vit_true_labels.tolist()
    }, f)

print("\n✅ Saved ViT report to:", vit_report_path)
print("✅ Saved ViT probs to:", vit_probs_path)
# Out:
# 📊 Classification Report (ViT):
#
#               precision    recall  f1-score   support
#
#         Fake     0.6295    0.5556    0.5902       477
#         Real     0.6045    0.6750    0.6378       480
#
#     accuracy                         0.6155       957
#    macro avg     0.6170    0.6153    0.6140       957
# weighted avg     0.6169    0.6155    0.6141       957
# ✅ Saved ViT report to: /content/drive/MyDrive/MultiBanFake/outputs_vit/vit_classification_report_full.json
# ✅ Saved ViT probs to: /content/drive/MyDrive/MultiBanFake/outputs_vit/vit_stack_probs_full.json

# %%
from transformers import ViTForImageClassification
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

BEST_MODEL_PATH = "/content/drive/MyDrive/MultiBanFake/outputs_vit/vit_best_model"

model = ViTForImageClassification.from_pretrained(BEST_MODEL_PATH).to(device)
model.eval()

print("Loaded best model!")
# Out:
# Loaded best model!

# %%
import torch.nn.functional as F

@torch.no_grad()
def get_softmax_probs(model, dataloader, device):
    all_probs = []
    all_labels = []

    model.eval()

    for batch in dataloader:
        imgs = batch["pixel_values"].to(device)
        labels = batch["labels"].cpu().numpy()

        outputs = model(imgs)
        logits = outputs.logits  # [B, 2]

        probs = F.softmax(logits, dim=-1).cpu().numpy()

        all_probs.append(probs)
        all_labels.append(labels)

    all_probs = np.concatenate(all_probs, axis=0)
    all_labels = np.concatenate(all_labels, axis=0)

    return all_probs, all_labels

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from torchvision import transforms

# %%
DATA_ROOT = "/content/drive/MyDrive/MultiBanFake/preprocessed"

train_npz = np.load(f"{DATA_ROOT}/train_npz.npz")
val_npz   = np.load(f"{DATA_ROOT}/val_npz.npz")
test_npz  = np.load(f"{DATA_ROOT}/test_npz.npz")

X_val = val_npz["images"]
y_val = val_npz["labels"]

X_test = test_npz["images"]
y_test = test_npz["labels"]

print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (957, 224, 224, 3) (957,)
# (957, 224, 224, 3) (957,)

# %%
processor = ViTImageProcessor.from_pretrained("google/vit-base-patch16-224-in21k")

eval_transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=processor.image_mean, std=processor.image_std),
])

# %%
class ImageTensorDataset(Dataset):
    def __init__(self, images, labels, transform=None):
        self.images = images
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        img = self.images[idx]
        lbl = int(self.labels[idx])

        img = Image.fromarray(img)

        if self.transform:
            img = self.transform(img)

        return {
            "pixel_values": img,
            "labels": torch.tensor(lbl, dtype=torch.long)
        }

# %%
val_dataset  = ImageTensorDataset(X_val,  y_val,  eval_transform)
test_dataset = ImageTensorDataset(X_test, y_test, eval_transform)

val_dataloader  = DataLoader(val_dataset,  batch_size=32, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)

print("VAL batches :", len(val_dataloader))
print("TEST batches:", len(test_dataloader))
# Out:
# VAL batches : 30
# TEST batches: 30

# %%
val_probs, val_labels = get_softmax_probs(model, val_dataloader, device)
test_probs, test_labels = get_softmax_probs(model, test_dataloader, device)

print(val_probs.shape, test_probs.shape)
# Out:
# (957, 2) (957, 2)

# %%
import numpy as np

SAVE_DIR = "/content/drive/MyDrive/MultiBanFake/vit_outputs"
os.makedirs(SAVE_DIR, exist_ok=True)

np.save(os.path.join(SAVE_DIR, "val_probs.npy"), val_probs)
np.save(os.path.join(SAVE_DIR, "val_labels.npy"), val_labels)

np.save(os.path.join(SAVE_DIR, "test_probs.npy"), test_probs)
np.save(os.path.join(SAVE_DIR, "test_labels.npy"), test_labels)

print("Saved softmax probabilities!")
# Out:
# Saved softmax probabilities!
